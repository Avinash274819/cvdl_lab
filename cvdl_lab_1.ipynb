# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\avika\appdata\local\programs\python\python312\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\avika\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.11.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('dog.jpg')

# %%
# Display the image
plt.imshow(img)
plt.show()

# %%
# Convert from BGR to RGB for proper color display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Display the image
plt.imshow(img_rgb)
plt.show()

# %%
img_rgb.shape
# Out:
# (612, 612, 3)

# %%
type(img_rgb)
# Out:
# numpy.ndarray

# %%
img_rgb[:,:,0]
# Out:
# array([[92, 92, 92, ..., 85, 84, 84],
#        [92, 92, 92, ..., 85, 84, 84],
#        [92, 92, 92, ..., 85, 84, 84],
#        ...,
#        [80, 80, 80, ..., 69, 69, 68],
#        [80, 80, 80, ..., 69, 69, 68],
#        [80, 80, 80, ..., 69, 69, 68]], dtype=uint8)

# %%
img_rgb[:,:,2].min()
# Out:
# 2

# %%
img_rgb[:,:,1]
# Out:
# array([[175, 175, 175, ..., 165, 164, 164],
#        [175, 175, 175, ..., 165, 164, 164],
#        [175, 175, 175, ..., 165, 164, 164],
#        ...,
#        [140, 140, 140, ..., 134, 134, 133],
#        [140, 140, 140, ..., 134, 134, 133],
#        [140, 140, 140, ..., 134, 134, 133]], dtype=uint8)

# %%
img_rgb[:,:,0]
# Out:
# array([[92, 92, 92, ..., 85, 84, 84],
#        [92, 92, 92, ..., 85, 84, 84],
#        [92, 92, 92, ..., 85, 84, 84],
#        ...,
#        [80, 80, 80, ..., 69, 69, 68],
#        [80, 80, 80, ..., 69, 69, 68],
#        [80, 80, 80, ..., 69, 69, 68]], dtype=uint8)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (612, 612)

# %%
# Display the image
plt.imshow(gray)
plt.show()

# %%
plt.imshow(gray, cmap='gray')  # Specify the color map as 'gray'
plt.show()

# %%
gray.shape
# Out:
# (612, 612)

# %%
type(gray)
# Out:
# numpy.ndarray

# %%
# Display the image
plt.imshow(img_rgb[:,:,0],cmap='gray')
plt.show()

# %%
# Display the image
plt.imshow(img_rgb[:,:,1],cmap='gray')
plt.show()

# %%
# Display the image
plt.imshow(img_rgb[:,:,2],cmap='gray')
plt.show()

# %%
# Create a figure
fig = plt.figure(figsize=(8, 6))  # Specify figure size in inches
# Add a single subplot to the figure
ax = fig.add_subplot(111)  # (1 row, 1 column, 1st subplot)
# Display the image
ax.imshow(img_rgb)
ax.axis('off')  # Turn off axis labels and ticks
ax.set_title("Image Display")  # Set a title for the subplot
# Show the figure
plt.show()

# %%
img_rgb.shape
# Out:
# (612, 612, 3)

# %%
resized = cv2.resize(img_rgb, (300, 300))

# %%
resized.shape
# Out:
# (300, 300, 3)

# %%
# Display the image
plt.imshow(resized)
plt.show()

# %%
# Create a figure
fig = plt.figure(figsize=(8, 6))  # Specify figure size in inches
# Add a single subplot to the figure
ax = fig.add_subplot(111)  # (1 row, 1 column, 1st subplot)
# Display the image
ax.imshow(resized)
ax.axis('off')  # Turn off axis labels and ticks
ax.set_title("Image Display")  # Set a title for the subplot
# Show the figure
plt.show()

# %%
cv2.line(img_rgb, (50, 50), (200, 50), (255, 0, 0), 5)
plt.imshow(img_rgb)
plt.show()

# %%
cv2.line(img_rgb, (50, 50), (200, 50), (255, 0, 0), 5)
cv2.rectangle(img_rgb, (60, 60), (160, 160), (0, 255, 0), 3)
cv2.circle(img_rgb, (120, 120), 40, (0, 0, 255))
plt.imshow(img_rgb)
plt.show()

# %%
img = cv2.imread('dog.jpg')

# %%
# Convert from BGR to RGB for proper color display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)
plt.show()

# %%
# Apply Gaussian Blur
gaussian_blur = cv2.GaussianBlur(img_rgb, (15, 15), 0)

# %%
plt.imshow(gaussian_blur)
plt.show()

# %%
# Apply Gaussian Blur
gaussian_blur = cv2.GaussianBlur(img_rgb, (3, 3), 0)
plt.imshow(gaussian_blur)
plt.show()

# %%
# Apply Sharpening Filter
kernel_sharpening = np.array([[0, -1, 0],
                              [-1, 5, -1],
                              [0, -1, 0]])
sharpened = cv2.filter2D(img_rgb, -1, kernel_sharpening)

# %%
plt.imshow(sharpened)
plt.show()

# %%
# Create a Contrast Filter
alpha = 1.5  # Contrast control (1.0-3.0) - increase for higher contrast
beta = 0     # Brightness control (0-100) - adjust if needed

# Apply Contrast Filter
contrast_enhanced = cv2.convertScaleAbs(img_rgb, alpha=alpha, beta=beta)

# %%
plt.imshow(contrast_enhanced)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray,cmap='gray')
plt.show()

# %%
# Apply Histogram Equalization
equalized_image = cv2.equalizeHist(gray)

# %%
plt.imshow(equalized_image,cmap='gray')
plt.show()

# %%
# Apply a Box Filter
kernel_size = (5, 5)  # Define the kernel size (width, height)
box_filtered = cv2.blur(img_rgb, kernel_size)

# %%
plt.imshow(box_filtered)
plt.show()
